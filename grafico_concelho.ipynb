# %% [markdown]
# # Gráfico Concelho

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import os

user = os.getenv('postgres')
password = os.getenv('claudia1998')
connection_string = "postgresql://postgres:claudia1998@localhost/miebiom".format(user=user, password=password)
# %sql $connection_string
# Out:
# 'Connected: postgres@miebiom'

# %%
result = %sql SELECT concelho, mais_recente FROM confirmados_concelho WHERE mais_recente > 500
# Out:
#  * postgresql://postgres:***@localhost/miebiom
# 11 rows affected.

# %%
# usando diretamente o resultado, em que type(result) = sql.run.ResultSet
# %matplotlib notebook
result.pie()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x1485cb41dd8>,
#   <matplotlib.patches.Wedge at 0x1485cb52320>,
#   <matplotlib.patches.Wedge at 0x1485cb52780>,
#   <matplotlib.patches.Wedge at 0x1485cb52c18>,
#   <matplotlib.patches.Wedge at 0x1485cb650f0>,
#   <matplotlib.patches.Wedge at 0x1485cb655c0>,
#   <matplotlib.patches.Wedge at 0x1485cb65a58>,
#   <matplotlib.patches.Wedge at 0x1485cb65ef0>,
#   <matplotlib.patches.Wedge at 0x1485cb723c8>,
#   <matplotlib.patches.Wedge at 0x1485cb72860>,
#   <matplotlib.patches.Wedge at 0x1485cb06710>],
#  [Text(1.0849974335199486, 0.1810540506454493, 'OVAR'),
#   Text(0.9627874685382707, 0.5320153103301339, 'SINTRA'),
#   Text(0.5821071315013063, 0.9333548561267152, 'MATOSINHOS'),
#   Text(-0.1516203478027613, 1.0895004681651907, 'PORTO'),
#   Text(-0.7856871748774095, 0.7698673023535648, 'GONDOMAR'),
#   Text(-1.097399704710426, 0.07559026459452266, 'VILA NOVA DE GAIA'),
#   Text(-0.9544201916252831, -0.5468839893596794, 'GUIMARÃES'),
#   Text(-0.5810141333927801, -0.934035640004083, 'BRAGA'),
#   Text(0.21540836280783413, -1.0787025712551392, 'LISBOA'),
#   Text(0.8544383460952156, -0.6927734930856352, 'MAIA'),
#   Text(1.0750617789670995, -0.23289948777121677, 'VALONGO')])

# %%
# usando pandas
df = result.DataFrame()    
df.plot.pie(y='mais_recente', labels=df['concelho'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#cria um grafico de barras
result.bar()
# Out:
# <BarContainer object of 11 artists>
